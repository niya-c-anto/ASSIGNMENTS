# %% [markdown]
# <a href="https://colab.research.google.com/github/niya-c-anto/ASSIGNMENTS/blob/main/AI_Python__Libraries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NUMPY

# %%
import numpy as np

# Create a 1D array
arr1 = np.array([1, 2, 3, 4, 5])
print(arr1)

# Create a 2D array (matrix)
arr2 = np.array([[1, 2, 3], [4, 5, 6]])
print("2D Array:\n", arr2)

# Perform element-wise operations
arr_sum = arr1 + 10
print("Array after addition:", arr_sum)

# Matrix multiplication
matrix_a = np.array([[1, 2], [3, 4]])
matrix_b = np.array([[5, 6], [7, 8]])
matrix_product = np.dot(matrix_a, matrix_b)
print("Matrix product:\n", matrix_product)
# Out:
# 1D Array: [1 2 3 4 5]
# 2D Array:
#  [[1 2 3]
#  [4 5 6]]
# Array after addition: [11 12 13 14 15]
# Matrix product:
#  [[19 22]
#  [43 50]]

# %%
import numpy as np

# Create array
arr = np.array([1, 2, 3, 4, 5])

# Perform operations
print(arr * 2)
print(np.mean(arr))
# Out:
# [ 2  4  6  8 10]
# 3.0

# %% [markdown]
# N-dimensional array

# %%
import numpy as np

arr = np.array([[1, 2, 3],
                [4, 5, 6]])

print(arr)
print("Shape:", arr.shape)
print("Type:", type(arr))
# Out:
# [[1 2 3]
#  [4 5 6]]
# Shape: (2, 3)
# Type: <class 'numpy.ndarray'>

# %% [markdown]
# Vectorised Operations

# %%
import numpy as np

arr = np.array([1, 2, 3, 4])

# Add 10 to every element
print(arr + 10)

# Square every element
print(arr ** 2)
# Out:
# [11 12 13 14]
# [ 1  4  9 16]

# %% [markdown]
# Broadcasting

# %%
import numpy as np

matrix = np.array([[1, 2, 3],
                   [4, 5, 6]])

vector = np.array([10, 20, 30])

# vector is broadcast across each row
result = matrix + vector

print(result)
# Out:
# [11 12 13 14]
# [ 1  4  9 16]

# %% [markdown]
# mathematical functions

# %%
import numpy as np

arr = np.array([0, np.pi/2, np.pi])

print("Sin:", np.sin(arr))
print("Mean:", np.mean(arr))
print("Square root:", np.sqrt([4, 9, 16]))
# Out:
# Sin: [0.0000000e+00 1.0000000e+00 1.2246468e-16]
# Mean: 1.5707963267948966
# Square root: [2. 3. 4.]

# %% [markdown]
# performance(pythonlist vs Numpy array

# %%
import numpy as np
import time

python_list = list(range(1_000_000))
numpy_array = np.arange(1_000_000)

start = time.time()
[x * 2 for x in python_list]
print("Python list time:", time.time() - start)

start = time.time()
numpy_array * 2
print("NumPy time:", time.time() - start)
# Out:
# Python list time: 0.06669449806213379
# NumPy time: 0.00421905517578125

# %% [markdown]
# Data manupulation&Preprocessing

# %%
import numpy as np

data = np.array([10, 20, 30, 40])

# Normalization
normalized = (data - np.min(data)) / (np.max(data) - np.min(data))
print(normalized)
# Out:
# [0.         0.33333333 0.66666667 1.        ]

# %% [markdown]
# Mathematical & Statistical Operations

# %%
import numpy as np

arr = np.array([5, 10, 15, 20])

print("Sum:", np.sum(arr))
print("Average:", np.mean(arr))
print("Standard deviation:", np.std(arr))
# Out:
# Sum: 50
# Average: 12.5
# Standard deviation: 5.5901699437494745

# %% [markdown]
# Linear Algebra Computations

# %%
import numpy as np

A = np.array([[1, 2],
              [3, 4]])

B = np.array([[5, 6],
              [7, 8]])

# Matrix multiplication
print(np.dot(A, B))

# Determinant
print("Determinant:", np.linalg.det(A))
# Out:
# [[19 22]
#  [43 50]]
# Determinant: -2.0000000000000004

# %% [markdown]
# Random Number Generation

# %%
import numpy as np

# Random integers from 1 to 100 (5 numbers)
print(np.random.randint(1, 100, 5))

# Random 2x3 matrix
print(np.random.rand(2, 3))
# Out:
# [59  5 92  5 62]
# [[0.48978657 0.631346   0.63189656]
#  [0.01728202 0.68083678 0.54968323]]

# %% [markdown]
# Working with Matrices & Vectors

# %%
import numpy as np

matrix = np.array([[1, 2, 3],
                   [4, 5, 6]])

vector = np.array([1, 1, 1])

# Matrix + vector
print(matrix + vector)

# Transpose
print(matrix.T)
# Out:
# [[2 3 4]
#  [5 6 7]]
# [[1 4]
#  [2 5]
#  [3 6]]

# %% [markdown]
# Foundation for Other Libraries

# %%
import numpy as np
import pandas as pd

arr = np.array([10, 20, 30])
df = pd.DataFrame(arr, columns=["Values"])

print(df)
# Out:
#    Values
# 0      10
# 1      20
# 2      30

# %% [markdown]
# Pandas

# %%
import pandas as pd

# Create DataFrame
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Salary': [50000, 60000, 70000]
})

# Operations
print(df.mean(numeric_only=True))  # Average age and salary
print(df[df['Age'] > 28])  # Filter rows
# Out:
# Age          30.0
# Salary    60000.0
# dtype: float64
#       Name  Age  Salary
# 1      Bob   30   60000
# 2  Charlie   35   70000

# %% [markdown]
# Series (1D labeled array)

# %%
import pandas as pd

s = pd.Series([10, 20, 30, 40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# DataFrame (2D table)

# %%
import pandas as pd

data = {
    "Name": ["Asha", "John", "Rahul"],
    "Age": [21, 25, 24],
    "Marks": [88, 92, 85]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age  Marks
# 0   Asha   21     88
# 1   John   25     92
# 2  Rahul   24     85

# %% [markdown]
# Data Handling (Read/Write)

# %%
import pandas as pd

df = pd.read_csv("path") #specify the path
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-809446878.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("students.csv")
#       4 print(df.head())
#
# ...

# %% [markdown]
# Handle Missing Values

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "A": [1, 2, np.nan],
    "B": [4, np.nan, 6]
})

print(df.fillna(0))         # Replace NaN with 0
print(df.dropna())          # Drop rows containing NaN
print(df.drop_duplicates())
# Out:
#      A    B
# 0  1.0  4.0
# 1  2.0  0.0
# 2  0.0  6.0
#      A    B
# 0  1.0  4.0

# %% [markdown]
# Remove Duplicates

# %%
df = pd.DataFrame({
    "Name": ["Asha", "John", "Asha"],
    "Age": [21, 25, 21]
})

print(df.drop_duplicates())
# Out:
#    Name  Age
# 0  Asha   21
# 1  John   25

# %% [markdown]
# Using .loc[] (label-based)

# %%
print(df.loc[0, "Name"])
print(df.loc[:, "Name"])
# Out:
# Asha
# 0    Asha
# 1    John
# 2    Asha
# Name: Name, dtype: object

# %% [markdown]
# Using .iloc[] (position-based)

# %%
print(df.iloc[0, 1])
n
# Out:
# 21

# %% [markdown]
# Boolean Filtering

# %%
print(df[df["Age"] > 22])
# Out:
#    Name  Age
# 1  John   25

# %% [markdown]
# Sorting,Grouping,Merging

# %%
print(df.sort_values("Age"))
grouped = df.groupby("Age").size()
print(grouped)
import pandas as pd

students = pd.DataFrame({
    "ID": [1, 2, 3],
    "Name": ["Asha", "John", "Rahul"]
})

marks = pd.DataFrame({
    "ID": [1, 2, 3],
    "Marks": [88, 92, 85]
})

merged = pd.merge(students, marks, on="ID")
print(merged)
# Out:
#    Name  Age
# 0  Asha   21
# 2  Asha   21
# 1  John   25
# Age
# 21    2
# 25    1
# dtype: int64
#    ID   Name  Marks
# 0   1   Asha     88
# 1   2   John     92
# 2   3  Rahul     85

# %% [markdown]
# Pivot Table

# %%
df = pd.DataFrame({
    "City": ["Kochi", "Kochi", "Delhi"],
    "Year": [2022, 2023, 2022],
    "Sales": [100, 150, 200]
})

pivot = df.pivot_table(values="Sales", index="City", columns="Year")
print(pivot)
# Out:
# Year    2022   2023
# City
# Delhi  200.0    NaN
# Kochi  100.0  150.0

# %% [markdown]
# Time Series Support

# %%
import pandas as pd

dates = pd.date_range(start="2024-01-01", periods=5, freq="D")
df = pd.DataFrame({"Date": dates, "Sales": [10, 20, 30, 40, 50]})

df["Date"] = pd.to_datetime(df["Date"])
df.set_index("Date", inplace=True)

print(df.resample("2D").sum())   # 2-day resampling
# Out:
#             Sales
# Date
# 2024-01-01     30
# 2024-01-03     70
# 2024-01-05     50

# %% [markdown]
# Statistical Analysis

# %%
import pandas as pd

df = pd.DataFrame({"Marks": [80, 90, 85, 95]})

print("Mean:", df["Marks"].mean())
print("Median:", df["Marks"].median())
print("Std Dev:", df["Marks"].std())
print("Describe:\n", df.describe())
# Out:
# Mean: 87.5
# Median: 87.5
# Std Dev: 6.454972243679028
# Describe:
#             Marks
# count   4.000000
# mean   87.500000
# std     6.454972
# min    80.000000
# 25%    83.750000
# 50%    87.500000
# 75%    91.250000
# max    95.000000

# %% [markdown]
# Data Cleaning & Preprocessing

# %%
df["Marks"] = df["Marks"].fillna(df["Marks"].mean())
df = df.drop_duplicates()

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %%
print(df.info())
print(df.describe())
print(df.corr())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Marks   4 non-null      int64
# dtypes: int64(1)
# memory usage: 164.0 bytes
# None
#            Marks
# count   4.000000
# mean   87.500000
# std     6.454972
# min    80.000000
# 25%    83.750000
# 50%    87.500000
# 75%    91.250000
# max    95.000000
#        Marks
# Marks    1.0

# %% [markdown]
# Data Wrangling & Transformation

# %%
df["Percentage"] = df["Marks"] / df["Marks"].max() * 100
print(df)
# Out:
#    Marks  Percentage
# 0     80   84.210526
# 1     90   94.736842
# 2     85   89.473684
# 3     95  100.000000

# %% [markdown]
# Working With CSV/Excel Files

# %%
df = pd.read_excel("students.xlsx")
df.to_csv("new_data.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3505435891.py in <cell line: 0>()
# ----> 1 df = pd.read_excel("students.xlsx")
#       2 df.to_csv("new_data.csv", index=False)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %% [markdown]
# Preparing Data for Machine Learning

# %%
from sklearn.model_selection import train_test_split

X = df[["Age"]]
y = df["Marks"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
print(X_train.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-207393489.py in <cell line: 0>()
#       1 from sklearn.model_selection import train_test_split
#       2
# ----> 3 X = df[["Age"]]
#       4 y = df["Marks"]
#       5
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
# ...

# %% [markdown]
# Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some sample data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a line plot
plt.plot(x, y)

# Add labels and a title
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Simple Sine Wave Plot")

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Simple line plot
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y, label='sin(x)')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Sine Wave')
plt.legend()
plt.grid(True)
plt.show()

# %%
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y)
plt.title("Simple Line Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
students = ["Niya", "Arun", "Sara"]
marks = [85, 90, 78]

plt.bar(students, marks, color='skyblue')
plt.title("Student Marks")
plt.xlabel("Name")
plt.ylabel("Marks")
plt.show()

# %%
labels = ['AI', 'ML', 'Python']
sizes = [40, 35, 25]

plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title("Subject Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter([1, 2, 3, 4], [10, 20, 15, 25])
plt.title("Scatter Plot")
plt.show()

# %%
import numpy as np

data = np.random.randn(1000)
plt.hist(data, bins=30)
plt.title("Histogram")
plt.show()

# %%
import numpy as np
data = np.random.rand(5, 5)

plt.imshow(data, cmap="viridis")
plt.colorbar()
plt.title("Heatmap")
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].plot([1, 2, 3], [2, 4, 6])
axes[0].set_title("Plot 1")

axes[1].bar(["A", "B", "C"], [3, 5, 2])
axes[1].set_title("Plot 2")

plt.show()

# %%
t = np.linspace(0, 2*np.pi, 200)
plt.plot(t, np.sin(t), label="sin(t)")
plt.plot(t, np.cos(t), label="cos(t)")
plt.legend()
plt.show()

# %%
df.plot(kind="bar", x="Year", y="Sales")
plt.title("Sales Comparison")
plt.show()

# %% [markdown]
# Dictionary

# %%
# Create a dictionary
student = {
    "name": "Niya",
    "age": 22,
    "course": "AI"
}

# Access values
print(student["name"])  # Niya

# Add or update
student["grade"] = "A"

# Remove
student.pop("age")

# Loop through
for key, value in student.items():
    print(key, ":", value)
# Out:
# Niya
# name : Niya
# course : AI
# grade : A

# %%
# Create a dictionary
student = {
    "name": "Niya",
    "age": 22,
    "course": "AI"
}

# Access values
print(student["name"])  # Niya

# Add or update
student["grade"] = "A"

# Remove
student.pop("age")

# Loop through
for key, value in student.items():
    print(key, ":", value)
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# WHILE LOOP

# %%
count=0
while count<5:
  print(count)
  count+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# SET

# %%
# Create a set
numbers = {1, 2, 3, 3, 2}

# Duplicate values are ignored
print(numbers)  # {1, 2, 3}

# Add and remove
numbers.add(4)
numbers.remove(2)

# Loop through
for n in numbers:
    print(n)
# Out:
# {1, 2, 3}
# 1
# 3
# 4

# %%
my_set={1,2,3}
empty_set=set()
my_set.add(4)
print(my_set)
my_set.remove(2)
print(my_set)
my_set.clear()
print(my_set)
# Out:
# {1, 2, 3, 4}
# {1, 3, 4}
# set()

# %% [markdown]
# TUPLE

# %%
# Create a tuple
colors = ("red", "green", "blue")

# Access items
print(colors[1])  # green

# Tuples cannot be changed
# colors[1] = "yellow" ❌ (Error)

# Loop through tuple
for c in colors:
    print(c)
# Out:
# green
# red
# green
# blue

# %% [markdown]
# LIST

# %%
my_list=[1,"hello",true,3.14]
empty_list=[]
my_list.append(4)
print(my_list)
another_list=[4,5]
my_list.extend(another_list)
my_list.insert(2,"world")
print(my_list)
removed_item=my_list.pop(2)
print(removed_item)
my_list.remove("hello")
print(my_list)
my_list.clear()
print(my_list)
my_list.sort()
print(my_list)
my_list.reverse()
print(my_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1514683452.py in <cell line: 0>()
# ----> 1 my_list=[1,"hello",true,3.14]
#       2 empty_list=[]
#       3 my_list.append(4)
#       4 print(my_list)
#       5 another_list=[4,5]
#
# NameError: name 'true' is not defined

# %%
# Create a list
fruits = ["apple", "banana", "cherry"]
print (fruits)

# Access items
print(fruits[0])       # apple

# Modify items
fruits[1] = "orange"

# Add and remove items
fruits.append("mango")
fruits.remove("apple")

# Loop through list
for f in fruits:
    print(f)
# Out:
# ['apple', 'banana', 'cherry']
# apple
# orange
# cherry
# mango

# %% [markdown]
# Pattern

# %%
rows = int(input("Enter the number of rows: "))

i = 1
while i <= rows:
    j = 1
    while j <= i:
        print("*", end=" ")
        j += 1
    print()  # Move to the next line after printing each row
    i += 1

# %%
rows = 5
i = 1

while i <= rows:
    print(" " * (rows - i) + "*" * (2 * i - 1))
    i += 1
